# %%
import os #Import os lib for the file operations
import pandas as pd #For data manipulation and analysis
import numpy as np #For data manipulation and analysis
import cv2 #Import cv2 library for video and image processing
import json #To read JSON files
import plotly.express as px #Visualization lib
from tqdm import tqdm #Process bar to see progress
import warnings
warnings.filterwarnings('ignore')

# %%
#Two experts labeled images and upload to Github. Labeled frames are in JSON format.
adress = 'https://raw.githubusercontent.com/kynemre/CellSegmentation/master/DATA/BothJsonFiles.zip'; #JSON files path
# !wget -q -O data.zip "{adress}"; # Download data as ZIP
# !unzip -q data.zip # Extract ZIP file
# !rm data.zip ## Delete ZIP file

DIR1Name = "ann_Emre" #Create folder name - expert1
DIR2Name = "ann_Tarik" #Create folder name - expert2
# Out:
# replace ann_Emre/frame1.jpg.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# This code block is to upload different data (labeled frames) in JSON format.
"""
DIR1Name = "Label_1" #Create a name for first folder
DIR2Name = "Label_2" #Create a name for second folder

# !mkdir "{DIR1Name}" #Create the first folder
# !mkdir "{DIR2Name}" #Create the second folder
""";

# %%
paths1 = os.listdir("/content/"+DIR1Name) #Adding the name of each JSON file in first folder to a list.
paths2 = os.listdir("/content/"+DIR2Name) #Adding the name of each JSON file in second folder to a list.
paths1.sort() #Sort the list
paths2.sort() #Sort the list

# %%
print("Check For Image Pairs")
for i in range(len(paths1)):
    print("{} and {} are pairing.".format(paths1[i], paths2[i]))
# Out:
# Check For Image Pairs
# frame1.jpg.json and Image1.png.json are pairing.
# frame13.jpg.json and Image13.png.json are pairing.
# frame15.jpg.json and Image15.png.json are pairing.
# frame153.jpg.json and Image153.png.json are pairing.
# frame213.jpg.json and Image213.png.json are pairing.
# frame217.jpg.json and Image217.png.json are pairing.
# frame28.jpg.json and Image28.png.json are pairing.
# frame3.jpg.json and Image3.png.json are pairing.
# frame312.jpg.json and Image312.png.json are pairing.
# frame34.jpg.json and Image34.png.json are pairing.
# frame358.jpg.json and Image358.png.json are pairing.
# frame493.jpg.json and Image493.png.json are pairing.
# frame579.jpg.json and Image579.png.json are pairing.
# frame75.jpg.json and Image75.png.json are pairing.
# frame8.jpg.json and Image8.png.json are pairing.

# %% [markdown]
# #Dice Score

# %%
print("Dice Similarity Coefficient\n") 

for i in range(len(paths1)): #Loop for data
    with open("/content/"+DIR1Name+"/"+paths1[i]) as f: #Open expert 1 data file
        seg = json.load(f) #Read the data file
    with open("/content/"+DIR2Name+"/"+paths2[i]) as f: #Open expert 2 data file
        gt = json.load(f) #Read the data file

    HEIGHT = seg["size"]["height"] #Get the height of output from data
    WIDTH = seg["size"]["width"] #Get the width of output from data

    for j in range(len(seg["objects"])): #Draw each object(cell) of expert 1
        
        img_seg = np.zeros((HEIGHT,WIDTH)) #Create a canvas for output
        contours = np.array(seg["objects"][j]["points"]["exterior"]) #Get the corners
        cv2.fillPoly(img_seg, pts =[contours], color=(1,1,1)) #Add the object to the canvas
        
        found = False #For checking that is there same object/cell at the frame of expert 1 and expert 2
        for k in range(len(gt["objects"])):#Draw each object(cell) of expert 2 and compare
            
            if seg["objects"][j]["tags"][0]["name"] == gt["objects"][k]["tags"][0]["name"]: #Find the same cell at the frame of expert 1 and expert 2
                found = True #True if there is same cell at both frames
                img_gt = np.zeros((HEIGHT,WIDTH)) #Create a canvas
                contours = np.array(gt["objects"][k]["points"]["exterior"])#Get the corners
                cv2.fillPoly(img_gt, pts =[contours], color=(1,1,1)) #Add the object to the canvas

                dice = np.sum(img_seg[img_gt==1])*2.0 / (np.sum(img_seg) + np.sum(img_gt))#Calculate the dice score

                print('The {cell1} in the {data1} and the {cell2} in the {data2} consistence %{dice_score}'.format(
                    data1=paths1[i][:-5],
                    cell1=seg["objects"][j]["tags"][0]["name"],
                    data2=paths2[i][:-5],
                    cell2=gt["objects"][k]["tags"][0]["name"],
                    dice_score=round(dice*100,2)))#Print the comparison

        if not found:
            print("The {} in {} is not found".format(seg["objects"][j]["tags"][0]["name"],paths1[i][:-5]))
# Out:
# Dice Similarity Coefficient
#
# The Cell_6 in the frame1.jpg and the Cell_6 in the Image1.png consistence %95.77
# The Cell_5 in the frame1.jpg and the Cell_5 in the Image1.png consistence %93.65
# The Cell_2 in the frame1.jpg and the Cell_2 in the Image1.png consistence %95.66
# The Cell_8 in the frame1.jpg and the Cell_8 in the Image1.png consistence %94.39
# The Cell_7 in the frame1.jpg and the Cell_7 in the Image1.png consistence %97.44
# The Cell_1 in the frame1.jpg and the Cell_1 in the Image1.png consistence %96.44
# The Cell_3 in the frame1.jpg and the Cell_3 in the Image1.png consistence %97.94
# The Cell_4 in the frame1.jpg and the Cell_4 in the Image1.png consistence %95.65
# The Cell_9 in the frame1.jpg and the Cell_9 in the Image1.png consistence %96.71
# The Cell_6 in the frame13.jpg and the Cell_6 in the Image13.png consistence %95.49
# The Cell_5 in the frame13.jpg and the Cell_5 in the Image13.png consistence %96.51
# The Cell_7 in the frame13.jpg and the Cell_7 in the Image13.png consistence %95.36
# The Cell_2 in the frame13.jpg and the Cell_2 in the Image13.png consistence %93.79
# The Cell_8 in the frame13.jpg and the Cell_8 in the Image13.png consistence %93.45
# The Cell_1 in the frame13.jpg and the Cell_1 in the Image13.png consistence %93.08
# The Cell_3 in the frame13.jpg and the Cell_3 in the Image13.png consistence %95.76
# The Cell_4 in the frame13.jpg and the Cell_4 in the Image13.png consistence %97.19
# The Cell_9 in the frame13.jpg and the Cell_9 in the Image13.png consistence %94.7
# The Cell_6 in the frame15.jpg and the Cell_6 in the Image15.png consistence %94.69
# The Cell_5 in the frame15.jpg and the Cell_5 in the Image15.png consistence %96.58
# The Cell_7 in the frame15.jpg and the Cell_7 in the Image15.png consistence %94.57
# The Cell_2 in the frame15.jpg and the Cell_2 in the Image15.png consistence %96.53
# The Cell_8 in the frame15.jpg and the Cell_8 in the Image15.png consistence %94.47
# The Cell_1 in the frame15.jpg and the Cell_1 in the Image15.png consistence %93.93
# The Cell_3 in the frame15.jpg and the Cell_3 in the Image15.png consistence %96.77
# The Cell_4 in the frame15.jpg and the Cell_4 in the Image15.png consistence %95.85
# The Cell_9 in the frame15.jpg and the Cell_9 in the Image15.png consistence %95.25
# The Cell_6 in the frame153.jpg and the Cell_6 in the Image153.png consistence %96.03
# The Cell_5 in the frame153.jpg and the Cell_5 in the Image153.png consistence %96.54
# The Cell_7 in the frame153.jpg and the Cell_7 in the Image153.png consistence %93.35
# The Cell_2 in the frame153.jpg and the Cell_2 in the Image153.png consistence %96.37
# The Cell_8 in the frame153.jpg and the Cell_8 in the Image153.png consistence %97.25
# The Cell_4 in the frame153.jpg and the Cell_4 in the Image153.png consistence %96.01
# The Cell_9 in the frame153.jpg and the Cell_9 in the Image153.png consistence %96.19
# The Cell_3 in the frame153.jpg and the Cell_3 in the Image153.png consistence %89.57
# The Cell_1 in the frame153.jpg and the Cell_1 in the Image153.png consistence %92.53
# The Cell_10 in the frame153.jpg and the Cell_10 in the Image153.png consistence %95.33
# The Cell_6 in the frame213.jpg and the Cell_6 in the Image213.png consistence %93.94
# The Cell_5 in the frame213.jpg and the Cell_5 in the Image213.png consistence %97.54
# The Cell_9 in the frame213.jpg and the Cell_9 in the Image213.png consistence %94.54
# The Cell_7 in the frame213.jpg and the Cell_7 in the Image213.png consistence %94.8
# The Cell_2 in the frame213.jpg and the Cell_2 in the Image213.png consistence %93.87
# The Cell_8 in the frame213.jpg and the Cell_8 in the Image213.png consistence %98.0
# The Cell_1 in the frame213.jpg and the Cell_1 in the Image213.png consistence %94.77
# The Cell_4 in the frame213.jpg and the Cell_4 in the Image213.png consistence %94.4
# The Cell_3 in the frame213.jpg and the Cell_3 in the Image213.png consistence %89.57
# The Cell_6 in the frame217.jpg and the Cell_6 in the Image217.png consistence %96.25
# The Cell_5 in the frame217.jpg and the Cell_5 in the Image217.png consistence %97.51
# The Cell_7 in the frame217.jpg and the Cell_7 in the Image217.png consistence %94.15
# The Cell_8 in the frame217.jpg and the Cell_8 in the Image217.png consistence %97.79
# The Cell_9 in the frame217.jpg and the Cell_9 in the Image217.png consistence %94.61
# The Cell_2 in the frame217.jpg and the Cell_2 in the Image217.png consistence %95.69
# The Cell_1 in the frame217.jpg and the Cell_1 in the Image217.png consistence %91.98
# The Cell_4 in the frame217.jpg and the Cell_4 in the Image217.png consistence %95.96
# The Cell_6 in the frame28.jpg and the Cell_6 in the Image28.png consistence %94.45
# The Cell_5 in the frame28.jpg and the Cell_5 in the Image28.png consistence %97.86
# The Cell_7 in the frame28.jpg and the Cell_7 in the Image28.png consistence %94.98
# The Cell_2 in the frame28.jpg and the Cell_2 in the Image28.png consistence %96.83
# The Cell_8 in the frame28.jpg and the Cell_8 in the Image28.png consistence %97.99
# The Cell_1 in the frame28.jpg and the Cell_1 in the Image28.png consistence %90.86
# The Cell_3 in the frame28.jpg and the Cell_3 in the Image28.png consistence %97.36
# The Cell_4 in the frame28.jpg and the Cell_4 in the Image28.png consistence %97.41
# The Cell_9 in the frame28.jpg and the Cell_9 in the Image28.png consistence %96.06
# The Cell_6 in the frame3.jpg and the Cell_6 in the Image3.png consistence %95.82
# The Cell_5 in the frame3.jpg and the Cell_5 in the Image3.png consistence %94.82
# The Cell_7 in the frame3.jpg and the Cell_7 in the Image3.png consistence %96.41
# The Cell_2 in the frame3.jpg and the Cell_2 in the Image3.png consistence %93.01
# The Cell_8 in the frame3.jpg and the Cell_8 in the Image3.png consistence %93.67
# The Cell_1 in the frame3.jpg and the Cell_1 in the Image3.png consistence %93.55
# The Cell_3 in the frame3.jpg and the Cell_3 in the Image3.png consistence %95.31
# The Cell_4 in the frame3.jpg and the Cell_4 in the Image3.png consistence %96.78
# The Cell_9 in the frame3.jpg and the Cell_9 in the Image3.png consistence %97.31
# The Cell_7 in the frame312.jpg and the Cell_7 in the Image312.png consistence %93.35
# The Cell_8 in the frame312.jpg and the Cell_8 in the Image312.png consistence %96.98
# The Cell_2 in the frame312.jpg and the Cell_2 in the Image312.png consistence %95.35
# The Cell_1 in the frame312.jpg and the Cell_1 in the Image312.png consistence %91.63
# The Cell_4 in the frame312.jpg and the Cell_4 in the Image312.png consistence %94.16
# The Cell_6 in the frame312.jpg and the Cell_6 in the Image312.png consistence %94.52
# The Cell_5 in the frame312.jpg and the Cell_5 in the Image312.png consistence %96.36
# The Cell_3 in the frame312.jpg and the Cell_3 in the Image312.png consistence %92.32
# The Cell_6 in the frame34.jpg and the Cell_6 in the Image34.png consistence %97.28
# The Cell_5 in the frame34.jpg and the Cell_5 in the Image34.png consistence %98.25
# The Cell_7 in the frame34.jpg and the Cell_7 in the Image34.png consistence %97.12
# The Cell_2 in the frame34.jpg and the Cell_2 in the Image34.png consistence %97.52
# The Cell_8 in the frame34.jpg and the Cell_8 in the Image34.png consistence %98.19
# The Cell_1 in the frame34.jpg and the Cell_1 in the Image34.png consistence %95.4
# The Cell_3 in the frame34.jpg and the Cell_3 in the Image34.png consistence %97.35
# The Cell_4 in the frame34.jpg and the Cell_4 in the Image34.png consistence %97.12
# The Cell_9 in the frame34.jpg and the Cell_9 in the Image34.png consistence %94.86
# The Cell_4 in the frame358.jpg and the Cell_4 in the Image358.png consistence %93.3
# The Cell_1 in the frame358.jpg and the Cell_1 in the Image358.png consistence %95.77
# The Cell_2 in the frame358.jpg and the Cell_2 in the Image358.png consistence %94.48
# The Cell_8 in the frame358.jpg and the Cell_8 in the Image358.png consistence %95.77
# The Cell_7 in the frame358.jpg and the Cell_7 in the Image358.png consistence %95.43
# The Cell_6 in the frame358.jpg and the Cell_6 in the Image358.png consistence %91.86
# The Cell_5 in the frame358.jpg and the Cell_5 in the Image358.png consistence %94.2
# The Cell_3 in the frame358.jpg and the Cell_3 in the Image358.png consistence %93.47
# The Cell_4 in the frame493.jpg and the Cell_4 in the Image493.png consistence %94.34
# The Cell_7A in the frame493.jpg and the Cell_7A in the Image493.png consistence %95.76
# The Cell_8 in the frame493.jpg and the Cell_8 in the Image493.png consistence %95.32
# The Cell_6 in the frame493.jpg and the Cell_6 in the Image493.png consistence %91.06
# The Cell_5 in the frame493.jpg and the Cell_5 in the Image493.png consistence %92.9
# The Cell_3 in the frame493.jpg and the Cell_3 in the Image493.png consistence %95.47
# The Cell_2 in the frame493.jpg and the Cell_2 in the Image493.png consistence %91.94
# The Cell_7B in the frame493.jpg and the Cell_7B in the Image493.png consistence %97.63
# The Cell_11 in the frame493.jpg and the Cell_11 in the Image493.png consistence %93.04
# The Cell_9 in the frame493.jpg and the Cell_9 in the Image493.png consistence %79.84
# The Cell_8 in the frame579.jpg and the Cell_8 in the Image579.png consistence %96.51
# The Cell_4 in the frame579.jpg and the Cell_4 in the Image579.png consistence %96.87
# The Cell_6 in the frame579.jpg and the Cell_6 in the Image579.png consistence %91.74
# The Cell_5 in the frame579.jpg and the Cell_5 in the Image579.png consistence %92.55
# The Cell_11 in the frame579.jpg and the Cell_11 in the Image579.png consistence %92.51
# The Cell_1 in the frame579.jpg and the Cell_1 in the Image579.png consistence %92.39
# The Cell_7A in the frame579.jpg and the Cell_7A in the Image579.png consistence %95.98
# The Cell_7B in the frame579.jpg and the Cell_7B in the Image579.png consistence %97.22
# The Cell_9 in the frame579.jpg and the Cell_9 in the Image579.png consistence %85.2
# The Cell_3 in the frame579.jpg and the Cell_3 in the Image579.png consistence %88.91
# The Cell_6 in the frame75.jpg and the Cell_6 in the Image75.png consistence %94.87
# The Cell_5 in the frame75.jpg and the Cell_5 in the Image75.png consistence %97.77
# The Cell_7 in the frame75.jpg and the Cell_7 in the Image75.png consistence %93.27
# The Cell_2 in the frame75.jpg and the Cell_2 in the Image75.png consistence %96.53
# The Cell_8 in the frame75.jpg and the Cell_8 in the Image75.png consistence %94.45
# The Cell_1 in the frame75.jpg and the Cell_1 in the Image75.png consistence %95.86
# The Cell_3 in the frame75.jpg and the Cell_3 in the Image75.png consistence %93.86
# The Cell_4 in the frame75.jpg and the Cell_4 in the Image75.png consistence %93.33
# The Cell_9 in the frame75.jpg and the Cell_9 in the Image75.png consistence %95.5
# The Cell_5 in the frame8.jpg and the Cell_5 in the Image8.png consistence %95.85
# The Cell_7 in the frame8.jpg and the Cell_7 in the Image8.png consistence %95.31
# The Cell_2 in the frame8.jpg and the Cell_2 in the Image8.png consistence %95.57
# The Cell_8 in the frame8.jpg and the Cell_8 in the Image8.png consistence %91.74
# The Cell_1 in the frame8.jpg and the Cell_1 in the Image8.png consistence %94.43
# The Cell_3 in the frame8.jpg and the Cell_3 in the Image8.png consistence %93.47
# The Cell_4 in the frame8.jpg and the Cell_4 in the Image8.png consistence %95.03
# The Cell_9 in the frame8.jpg and the Cell_9 in the Image8.png consistence %94.84
# The Cell_6 in the frame8.jpg and the Cell_6 in the Image8.png consistence %96.94

# %% [markdown]
# #Jaccard Index

# %%
print("Jaccard Similarity Coefficient\n")

df_jaccard = pd.DataFrame(columns=['Name','Frame','Coefficient'])
for i in range(len(paths1)):#Loop for data
    with open("/content/"+DIR1Name+"/"+paths1[i]) as f: #Open expert 1 data file
        seg = json.load(f) #Read the data file
    with open("/content/"+DIR2Name+"/"+paths2[i]) as f: #Open expert 2 data file
        gt = json.load(f) #Read the data file

    HEIGHT = seg["size"]["height"] #Get the height of output from data
    WIDTH = seg["size"]["width"] #Get the widtgh of output from data

    for j in range(len(seg["objects"])): #Draw each object(cell) of expert 1
        
        img_seg = np.zeros((HEIGHT,WIDTH)) #Create a canvas for output
        contours = np.array(seg["objects"][j]["points"]["exterior"])#Get the corners
        cv2.fillPoly(img_seg, pts =[contours], color=(1,1,1))#Add the object to the canvas
        
        found = False #For checking that is there same object/cell at the frame of expert 1 and expert 2 
        for k in range(len(gt["objects"])): #Draw each object(cell) of expert 2 and compare
            
            if seg["objects"][j]["tags"][0]["name"] == gt["objects"][k]["tags"][0]["name"]: #Find the same cell at the frame of expert 1 and expert 2
                found = True #True if there is same cell at both frames
                img_gt = np.zeros((HEIGHT,WIDTH)) #Create a canvas
                contours = np.array(gt["objects"][k]["points"]["exterior"]) #Get the corners
                cv2.fillPoly(img_gt, pts =[contours], color=(1,1,1)) #Add the object to the canvas

                jaccard = np.sum(img_seg[img_gt==1])/ (np.sum(img_seg) + np.sum(img_gt) - np.sum(img_seg[img_gt==1]))#Calculate the score

                df_jaccard = df_jaccard.append(pd.DataFrame({
                    'Cell Tag': seg["objects"][j]["tags"][0]["name"],
                    'Number of Frame': gt["tags"][0]["value"],
                    'Jaccard': round(jaccard,2)
                }, index=[0]),ignore_index=True)

                print('The {cell1} in the {data1} and the {cell2} in the {data2} consistence %{jaccard_score}'.format(
                    data1=paths1[i][:-5],
                    cell1=seg["objects"][j]["tags"][0]["name"],
                    data2=paths2[i][:-5],
                    cell2=gt["objects"][k]["tags"][0]["name"],
                    jaccard_score=round(jaccard*100,2)))#Yazdirma islemi

            
        if not found:
            print("The {} in {} is not found.".format(seg["objects"][j]["tags"][0]["name"],paths1[i][:-5]))
# Out:
# Jaccard Similarity Coefficient
#
# The Cell_6 in the frame1.jpg and the Cell_6 in the Image1.png consistence %91.88
# The Cell_5 in the frame1.jpg and the Cell_5 in the Image1.png consistence %88.06
# The Cell_2 in the frame1.jpg and the Cell_2 in the Image1.png consistence %91.68
# The Cell_8 in the frame1.jpg and the Cell_8 in the Image1.png consistence %89.38
# The Cell_7 in the frame1.jpg and the Cell_7 in the Image1.png consistence %95.01
# The Cell_1 in the frame1.jpg and the Cell_1 in the Image1.png consistence %93.12
# The Cell_3 in the frame1.jpg and the Cell_3 in the Image1.png consistence %95.97
# The Cell_4 in the frame1.jpg and the Cell_4 in the Image1.png consistence %91.66
# The Cell_9 in the frame1.jpg and the Cell_9 in the Image1.png consistence %93.62
# The Cell_6 in the frame13.jpg and the Cell_6 in the Image13.png consistence %91.36
# The Cell_5 in the frame13.jpg and the Cell_5 in the Image13.png consistence %93.26
# The Cell_7 in the frame13.jpg and the Cell_7 in the Image13.png consistence %91.13
# The Cell_2 in the frame13.jpg and the Cell_2 in the Image13.png consistence %88.31
# The Cell_8 in the frame13.jpg and the Cell_8 in the Image13.png consistence %87.7
# The Cell_1 in the frame13.jpg and the Cell_1 in the Image13.png consistence %87.06
# The Cell_3 in the frame13.jpg and the Cell_3 in the Image13.png consistence %91.86
# The Cell_4 in the frame13.jpg and the Cell_4 in the Image13.png consistence %94.53
# The Cell_9 in the frame13.jpg and the Cell_9 in the Image13.png consistence %89.94
# The Cell_6 in the frame15.jpg and the Cell_6 in the Image15.png consistence %89.91
# The Cell_5 in the frame15.jpg and the Cell_5 in the Image15.png consistence %93.38
# The Cell_7 in the frame15.jpg and the Cell_7 in the Image15.png consistence %89.7
# The Cell_2 in the frame15.jpg and the Cell_2 in the Image15.png consistence %93.29
# The Cell_8 in the frame15.jpg and the Cell_8 in the Image15.png consistence %89.52
# The Cell_1 in the frame15.jpg and the Cell_1 in the Image15.png consistence %88.56
# The Cell_3 in the frame15.jpg and the Cell_3 in the Image15.png consistence %93.75
# The Cell_4 in the frame15.jpg and the Cell_4 in the Image15.png consistence %92.04
# The Cell_9 in the frame15.jpg and the Cell_9 in the Image15.png consistence %90.93
# The Cell_6 in the frame153.jpg and the Cell_6 in the Image153.png consistence %92.36
# The Cell_5 in the frame153.jpg and the Cell_5 in the Image153.png consistence %93.32
# The Cell_7 in the frame153.jpg and the Cell_7 in the Image153.png consistence %87.53
# The Cell_2 in the frame153.jpg and the Cell_2 in the Image153.png consistence %92.99
# The Cell_8 in the frame153.jpg and the Cell_8 in the Image153.png consistence %94.65
# The Cell_4 in the frame153.jpg and the Cell_4 in the Image153.png consistence %92.33
# The Cell_9 in the frame153.jpg and the Cell_9 in the Image153.png consistence %92.65
# The Cell_3 in the frame153.jpg and the Cell_3 in the Image153.png consistence %81.12
# The Cell_1 in the frame153.jpg and the Cell_1 in the Image153.png consistence %86.1
# The Cell_10 in the frame153.jpg and the Cell_10 in the Image153.png consistence %91.08
# The Cell_6 in the frame213.jpg and the Cell_6 in the Image213.png consistence %88.58
# The Cell_5 in the frame213.jpg and the Cell_5 in the Image213.png consistence %95.2
# The Cell_9 in the frame213.jpg and the Cell_9 in the Image213.png consistence %89.64
# The Cell_7 in the frame213.jpg and the Cell_7 in the Image213.png consistence %90.11
# The Cell_2 in the frame213.jpg and the Cell_2 in the Image213.png consistence %88.44
# The Cell_8 in the frame213.jpg and the Cell_8 in the Image213.png consistence %96.08
# The Cell_1 in the frame213.jpg and the Cell_1 in the Image213.png consistence %90.05
# The Cell_4 in the frame213.jpg and the Cell_4 in the Image213.png consistence %89.39
# The Cell_3 in the frame213.jpg and the Cell_3 in the Image213.png consistence %81.1
# The Cell_6 in the frame217.jpg and the Cell_6 in the Image217.png consistence %92.78
# The Cell_5 in the frame217.jpg and the Cell_5 in the Image217.png consistence %95.14
# The Cell_7 in the frame217.jpg and the Cell_7 in the Image217.png consistence %88.95
# The Cell_8 in the frame217.jpg and the Cell_8 in the Image217.png consistence %95.67
# The Cell_9 in the frame217.jpg and the Cell_9 in the Image217.png consistence %89.77
# The Cell_2 in the frame217.jpg and the Cell_2 in the Image217.png consistence %91.73
# The Cell_1 in the frame217.jpg and the Cell_1 in the Image217.png consistence %85.16
# The Cell_4 in the frame217.jpg and the Cell_4 in the Image217.png consistence %92.23
# The Cell_6 in the frame28.jpg and the Cell_6 in the Image28.png consistence %89.48
# The Cell_5 in the frame28.jpg and the Cell_5 in the Image28.png consistence %95.81
# The Cell_7 in the frame28.jpg and the Cell_7 in the Image28.png consistence %90.43
# The Cell_2 in the frame28.jpg and the Cell_2 in the Image28.png consistence %93.85
# The Cell_8 in the frame28.jpg and the Cell_8 in the Image28.png consistence %96.06
# The Cell_1 in the frame28.jpg and the Cell_1 in the Image28.png consistence %83.25
# The Cell_3 in the frame28.jpg and the Cell_3 in the Image28.png consistence %94.86
# The Cell_4 in the frame28.jpg and the Cell_4 in the Image28.png consistence %94.95
# The Cell_9 in the frame28.jpg and the Cell_9 in the Image28.png consistence %92.41
# The Cell_6 in the frame3.jpg and the Cell_6 in the Image3.png consistence %91.98
# The Cell_5 in the frame3.jpg and the Cell_5 in the Image3.png consistence %90.14
# The Cell_7 in the frame3.jpg and the Cell_7 in the Image3.png consistence %93.07
# The Cell_2 in the frame3.jpg and the Cell_2 in the Image3.png consistence %86.94
# The Cell_8 in the frame3.jpg and the Cell_8 in the Image3.png consistence %88.1
# The Cell_1 in the frame3.jpg and the Cell_1 in the Image3.png consistence %87.88
# The Cell_3 in the frame3.jpg and the Cell_3 in the Image3.png consistence %91.04
# The Cell_4 in the frame3.jpg and the Cell_4 in the Image3.png consistence %93.76
# The Cell_9 in the frame3.jpg and the Cell_9 in the Image3.png consistence %94.76
# The Cell_7 in the frame312.jpg and the Cell_7 in the Image312.png consistence %87.54
# The Cell_8 in the frame312.jpg and the Cell_8 in the Image312.png consistence %94.14
# The Cell_2 in the frame312.jpg and the Cell_2 in the Image312.png consistence %91.11
# The Cell_1 in the frame312.jpg and the Cell_1 in the Image312.png consistence %84.55
# The Cell_4 in the frame312.jpg and the Cell_4 in the Image312.png consistence %88.97
# The Cell_6 in the frame312.jpg and the Cell_6 in the Image312.png consistence %89.6
# The Cell_5 in the frame312.jpg and the Cell_5 in the Image312.png consistence %92.98
# The Cell_3 in the frame312.jpg and the Cell_3 in the Image312.png consistence %85.73
# The Cell_6 in the frame34.jpg and the Cell_6 in the Image34.png consistence %94.71
# The Cell_5 in the frame34.jpg and the Cell_5 in the Image34.png consistence %96.55
# The Cell_7 in the frame34.jpg and the Cell_7 in the Image34.png consistence %94.41
# The Cell_2 in the frame34.jpg and the Cell_2 in the Image34.png consistence %95.16
# The Cell_8 in the frame34.jpg and the Cell_8 in the Image34.png consistence %96.45
# The Cell_1 in the frame34.jpg and the Cell_1 in the Image34.png consistence %91.2
# The Cell_3 in the frame34.jpg and the Cell_3 in the Image34.png consistence %94.84
# The Cell_4 in the frame34.jpg and the Cell_4 in the Image34.png consistence %94.41
# The Cell_9 in the frame34.jpg and the Cell_9 in the Image34.png consistence %90.22
# The Cell_4 in the frame358.jpg and the Cell_4 in the Image358.png consistence %87.43
# The Cell_1 in the frame358.jpg and the Cell_1 in the Image358.png consistence %91.88
# The Cell_2 in the frame358.jpg and the Cell_2 in the Image358.png consistence %89.54
# The Cell_8 in the frame358.jpg and the Cell_8 in the Image358.png consistence %91.89
# The Cell_7 in the frame358.jpg and the Cell_7 in the Image358.png consistence %91.25
# The Cell_6 in the frame358.jpg and the Cell_6 in the Image358.png consistence %84.95
# The Cell_5 in the frame358.jpg and the Cell_5 in the Image358.png consistence %89.03
# The Cell_3 in the frame358.jpg and the Cell_3 in the Image358.png consistence %87.75
# The Cell_4 in the frame493.jpg and the Cell_4 in the Image493.png consistence %89.29
# The Cell_7A in the frame493.jpg and the Cell_7A in the Image493.png consistence %91.86
# The Cell_8 in the frame493.jpg and the Cell_8 in the Image493.png consistence %91.07
# The Cell_6 in the frame493.jpg and the Cell_6 in the Image493.png consistence %83.59
# The Cell_5 in the frame493.jpg and the Cell_5 in the Image493.png consistence %86.74
# The Cell_3 in the frame493.jpg and the Cell_3 in the Image493.png consistence %91.33
# The Cell_2 in the frame493.jpg and the Cell_2 in the Image493.png consistence %85.09
# The Cell_7B in the frame493.jpg and the Cell_7B in the Image493.png consistence %95.38
# The Cell_11 in the frame493.jpg and the Cell_11 in the Image493.png consistence %86.98
# The Cell_9 in the frame493.jpg and the Cell_9 in the Image493.png consistence %66.44
# The Cell_8 in the frame579.jpg and the Cell_8 in the Image579.png consistence %93.25
# The Cell_4 in the frame579.jpg and the Cell_4 in the Image579.png consistence %93.93
# The Cell_6 in the frame579.jpg and the Cell_6 in the Image579.png consistence %84.74
# The Cell_5 in the frame579.jpg and the Cell_5 in the Image579.png consistence %86.14
# The Cell_11 in the frame579.jpg and the Cell_11 in the Image579.png consistence %86.06
# The Cell_1 in the frame579.jpg and the Cell_1 in the Image579.png consistence %85.86
# The Cell_7A in the frame579.jpg and the Cell_7A in the Image579.png consistence %92.26
# The Cell_7B in the frame579.jpg and the Cell_7B in the Image579.png consistence %94.6
# The Cell_9 in the frame579.jpg and the Cell_9 in the Image579.png consistence %74.22
# The Cell_3 in the frame579.jpg and the Cell_3 in the Image579.png consistence %80.03
# The Cell_6 in the frame75.jpg and the Cell_6 in the Image75.png consistence %90.24
# The Cell_5 in the frame75.jpg and the Cell_5 in the Image75.png consistence %95.63
# The Cell_7 in the frame75.jpg and the Cell_7 in the Image75.png consistence %87.39
# The Cell_2 in the frame75.jpg and the Cell_2 in the Image75.png consistence %93.3
# The Cell_8 in the frame75.jpg and the Cell_8 in the Image75.png consistence %89.48
# The Cell_1 in the frame75.jpg and the Cell_1 in the Image75.png consistence %92.04
# The Cell_3 in the frame75.jpg and the Cell_3 in the Image75.png consistence %88.44
# The Cell_4 in the frame75.jpg and the Cell_4 in the Image75.png consistence %87.49
# The Cell_9 in the frame75.jpg and the Cell_9 in the Image75.png consistence %91.39
# The Cell_5 in the frame8.jpg and the Cell_5 in the Image8.png consistence %92.02
# The Cell_7 in the frame8.jpg and the Cell_7 in the Image8.png consistence %91.03
# The Cell_2 in the frame8.jpg and the Cell_2 in the Image8.png consistence %91.51
# The Cell_8 in the frame8.jpg and the Cell_8 in the Image8.png consistence %84.74
# The Cell_1 in the frame8.jpg and the Cell_1 in the Image8.png consistence %89.45
# The Cell_3 in the frame8.jpg and the Cell_3 in the Image8.png consistence %87.74
# The Cell_4 in the frame8.jpg and the Cell_4 in the Image8.png consistence %90.53
# The Cell_9 in the frame8.jpg and the Cell_9 in the Image8.png consistence %90.19
# The Cell_6 in the frame8.jpg and the Cell_6 in the Image8.png consistence %94.06

# %%
#Sort the outputs
df_jaccard['sort'] = df_jaccard['Cell Tag'].str.extract('(\d+)', expand=False).astype(int)
df_jaccard.sort_values(['Frame','sort'],inplace=True, ascending=True)
df_jaccard = df_jaccard.drop('sort', axis=1)

# %%
fig = px.scatter(df_jaccard,
                 x="Number of Frame",
                 y="Cell Tag",
                 color="Jaccard",
                 size= 1-df_jaccard["Jaccard"]/1.1,
                 size_max = 15,
                 width=1200,
                 height=600,
                 title="Comparison of Expert Labelings",
                 )
fig.show()
# fig.write_image("Comparison_of_Expert_Labelings.png", scale=1.5) #Save the static chart
# fig.write_html("Comparison_of_Expert_Labelings.html") #Save the interactive chart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0f3fe5c9-a70d-4416-8695-1dfcc3ed8342" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f3fe5c9-a70d-4416-8695-1dfcc3ed8342")) {                    Plotly.newPlot(                        "0f3fe5c9-a70d-4416-8695-1dfcc3ed8342",                        [{"hovertemplate":"Number of Frame=%{x}<br>Cell Tag=%{y}<br>size=%{marker.size}<br>Jaccard=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.93,0.87,0.89,0.86,0.9,0.85,0.83,0.88,0.85,0.91,0.92,0.86,0.92,0.89,0.92,0.88,0.93,0.93,0.88,0.92,0.94,0.87,0.91,0.95,0.9,0.85,0.93,0.92,0.96,0.92,0.94,0.81,0.81,0.95,0.91,0.86,0.95,0.88,0.91,0.8,0.88,0.88,0.92,0.95,0.92,0.92,0.89,0.92,0.95,0.94,0.89,0.94,0.87,0.89,0.94,0.87,0.91,0.88,0.93,0.93,0.93,0.95,0.95,0.96,0.9,0.93,0.97,0.89,0.87,0.86,0.96,0.92,0.92,0.91,0.9,0.92,0.89,0.93,0.89,0.92,0.9,0.95,0.85,0.84,0.85,0.9,0.94,0.95,0.91,0.9,0.88,0.9,0.89,0.9,0.93,0.88,0.94,0.91,0.92,0.95,0.92,0.95,0.87,0.91,0.89,0.88,0.9,0.95,0.96,0.96,0.96,0.88,0.94,0.96,0.92,0.91,0.93,0.89,0.85,0.94,0.9,0.91,0.93,0.9,0.9,0.92,0.95,0.9,0.66,0.74,0.91,0.9,0.91,0.87,0.86],"coloraxis":"coloraxis","size":[0.15454545454545454,0.2090909090909091,0.19090909090909092,0.21818181818181825,0.18181818181818188,0.2272727272727274,0.2454545454545456,0.20000000000000007,0.2272727272727274,0.17272727272727273,0.1636363636363637,0.21818181818181825,0.1636363636363637,0.19090909090909092,0.1636363636363637,0.20000000000000007,0.15454545454545454,0.15454545454545454,0.20000000000000007,0.1636363636363637,0.14545454545454561,0.2090909090909091,0.17272727272727273,0.13636363636363646,0.18181818181818188,0.2272727272727274,0.15454545454545454,0.1636363636363637,0.12727272727272743,0.1636363636363637,0.14545454545454561,0.26363636363636367,0.26363636363636367,0.13636363636363646,0.17272727272727273,0.21818181818181825,0.13636363636363646,0.20000000000000007,0.17272727272727273,0.2727272727272727,0.20000000000000007,0.20000000000000007,0.1636363636363637,0.13636363636363646,0.1636363636363637,0.1636363636363637,0.19090909090909092,0.1636363636363637,0.13636363636363646,0.14545454545454561,0.19090909090909092,0.14545454545454561,0.2090909090909091,0.19090909090909092,0.14545454545454561,0.2090909090909091,0.17272727272727273,0.20000000000000007,0.15454545454545454,0.15454545454545454,0.15454545454545454,0.13636363636363646,0.13636363636363646,0.12727272727272743,0.18181818181818188,0.15454545454545454,0.11818181818181828,0.19090909090909092,0.2090909090909091,0.21818181818181825,0.12727272727272743,0.1636363636363637,0.1636363636363637,0.17272727272727273,0.18181818181818188,0.1636363636363637,0.19090909090909092,0.15454545454545454,0.19090909090909092,0.1636363636363637,0.18181818181818188,0.13636363636363646,0.2272727272727274,0.23636363636363644,0.2272727272727274,0.18181818181818188,0.14545454545454561,0.13636363636363646,0.17272727272727273,0.18181818181818188,0.20000000000000007,0.18181818181818188,0.19090909090909092,0.18181818181818188,0.15454545454545454,0.20000000000000007,0.14545454545454561,0.17272727272727273,0.1636363636363637,0.13636363636363646,0.1636363636363637,0.13636363636363646,0.2090909090909091,0.17272727272727273,0.19090909090909092,0.20000000000000007,0.18181818181818188,0.13636363636363646,0.12727272727272743,0.12727272727272743,0.12727272727272743,0.20000000000000007,0.14545454545454561,0.12727272727272743,0.1636363636363637,0.17272727272727273,0.15454545454545454,0.19090909090909092,0.2272727272727274,0.14545454545454561,0.18181818181818188,0.17272727272727273,0.15454545454545454,0.18181818181818188,0.18181818181818188,0.1636363636363637,0.13636363636363646,0.18181818181818188,0.4,0.3272727272727274,0.17272727272727273,0.18181818181818188,0.1727272 ...
